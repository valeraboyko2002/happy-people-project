# %% [markdown]
# ### НАЧАЛО

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.3
# bleach                    6.3.0
# certifi                   2025.11.12
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.19
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.61.1
# fqdn                      1.5.1
# h11                       0.16.0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

df = pd.read_csv('data/world_happiness_2024.csv', sep = ';', decimal=',')
df.head()
# Out:
#    Ranking      Country                  Regional indicator  Ladder score  \
# 0      140  Afghanistan                          South Asia        1.7210
# 1       86      Albania          Central and Eastern Europe        5.3042
# 2       84      Argelia                  Sub-Saharan Africa        5.3635
# 3       48    Argentina         Latin America and Caribbean        6.1881
# 4       81      Armenia  Commonwealth of Independent States        5.4549
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0         2.93451         0.00000                       62
# 1         6.71748         0.57133                       74
# 2         6.18327         0.73652                       72
# 3         7.29612         0.85449                       73
# 4         6.74410         0.71415                       73
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                       0.00000     0.22638                    0.15383
# ...

# %% [markdown]
# ### АНАЛИЗ

# %%
df.columns
# Out:
# Index(['Ranking', 'Country', 'Regional indicator', 'Ladder score',
#        'GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Ranking                           int64
# Country                          object
# Regional indicator               object
# Ladder score                    float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy           int64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
numeric_columns = ['Ladder score', 'GDP per capita', 'Social support', 
                   'Healthy life expectancy', 'Freedom to make life choices', 
                   'Generosity', 'Perceptions of corruption']
numeric_columns
# Out:
# ['Ladder score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
df.describe()
# Out:
#         Ranking  Ladder score  GDP per capita  Social support  \
# count  140.0000    140.000000      140.000000      140.000000
# mean    70.5000      5.530882        6.441332        0.701704
# std     40.5586      1.181221        1.985895        0.206188
# min      1.0000      1.721000        0.000000        0.000000
# 25%     35.7500      4.631600        5.033228        0.569993
# 50%     70.5000      5.800600        6.686325        0.765350
# 75%    105.2500      6.426050        8.134660        0.855785
# max    140.0000      7.740700       10.000000        1.000000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               140.000000                    140.000000  140.000000
# mean                 70.828571                      0.718830    0.365076
# std                   4.991998                      0.188223    0.183260
# min                  55.000000                      0.000000    0.000000
# ...

# %%
df.shape
# Out:
# (140, 10)

# %% [markdown]
# *Самые счастливые страны*

# %%
df.nlargest(10, 'Ladder score')
# Out:
#      Ranking      Country            Regional indicator  Ladder score  \
# 39         1      Finland                Western Europe        7.7407
# 31         2      Denmark                Western Europe        7.5827
# 52         3      Iceland                Western Europe        7.5251
# 120        4       Sweden                Western Europe        7.3441
# 58         5       Israel  Middle East and North Africa        7.3411
# 93         6  Netherlands                Western Europe        7.3194
# 99         7       Norway                Western Europe        7.3017
# 76         8   Luxembourg                Western Europe        7.1219
# 121        9  Switzerland                Western Europe        7.0602
# 5         10    Australia         North America and ANZ        7.0569
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 39          8.61498         0.97268                       76
# 31          8.91278         0.94051                       76
# ...

# %%
df[df.Country == "Russia"]
# Out:
#      Ranking Country                  Regional indicator  Ladder score  \
# 108       71  Russia  Commonwealth of Independent States        5.7853
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 108         7.67194         0.83586                       71
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 108                       0.63875     0.34384                    0.20957

# %% [markdown]
# *Самые коррумпированные страны*

# %%
df.nsmallest(10, 'Perceptions of corruption')
# Out:
#      Ranking                 Country                  Regional indicator  \
# 12        64  Bosnia and Herzegovina          Central and Eastern Europe
# 15        80                Bulgaria          Central and Eastern Europe
# 107       32                 Romania          Central and Eastern Europe
# 98        83         North Macedonia          Central and Eastern Europe
# 126      112                 Tunisia        Middle East and North Africa
# 97       100                 Nigeria                  Sub-Saharan Africa
# 124       58                Thailand                      Southeast Asia
# 129      102                 Ukraine  Commonwealth of Independent States
# 45       117                   Ghana                  Sub-Saharan Africa
# 61        66                 Jamaica         Latin America and Caribbean
#
#      Ladder score  GDP per capita  Social support  Healthy life expectancy  \
# 12         5.8770         6.84293         0.81541                       73
# ...

# %% [markdown]
# *Самые несчастливые страны*

# %%
df.nsmallest(10, 'Ladder score')
# Out:
#      Ranking           Country            Regional indicator  Ladder score  \
# 0        140       Afghanistan                    South Asia        1.7210
# 71       139           Lebanon  Middle East and North Africa        2.7065
# 72       138           Lesotho            Sub-Saharan Africa        3.1862
# 112      137      Sierra Leone            Sub-Saharan Africa        3.2452
# 26       136  Congo (Kinshasa)            Sub-Saharan Africa        3.2954
# 139      135          Zimbabwe            Sub-Saharan Africa        3.3411
# 13       134          Botswana            Sub-Saharan Africa        3.3834
# 78       133            Malawi            Sub-Saharan Africa        3.4210
# 37       132          Eswatini            Sub-Saharan Africa        3.5020
# 138      131            Zambia            Sub-Saharan Africa        3.5024
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0           2.93451         0.00000                       62
# ...

# %% [markdown]
# ВВП vs Уровень счастья

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(df['GDP per capita'], df['Ladder score'], alpha=0.6)
plt.xlabel('GDP per capita')
plt.ylabel('Ladder score (Happiness)')
plt.title('GDP vs Happiness Score')
plt.grid(True, alpha=0.3)

# %% [markdown]
# 10 счастливых стран (горизонтальные бары)

# %%
import matplotlib.pyplot as plt

top_10 = df.nlargest(10, 'Ladder score')

plt.subplot(1, 2, 2)
top_10_sorted = top_10.sort_values('Ladder score')
plt.barh(top_10_sorted['Country'], top_10_sorted['Ladder score'])
plt.xlabel('Ladder score')
plt.title('Top 10 Happiest Countries')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Ladder score'], kde=True, color='skyblue')
plt.title('Гистограмма счастья')
plt.xlabel('Счастье')
plt.ylabel('Частота')
plt.tight_layout()
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
if numeric_df.shape[1] >= 4:
    plt.figure(figsize=(12, 8))
    corr = numeric_df.corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Тепловая карта корреляций')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Худшие страны

# %%
import matplotlib.pyplot as plt

top_10 = df.nsmallest(10, 'Ladder score')

plt.subplot(1, 2, 2)
top_10_sorted = top_10.sort_values('Ladder score')
plt.barh(top_10_sorted['Country'], top_10_sorted['Ladder score'])
plt.xlabel('Ladder score')
plt.title('Top 10 Happiest Countries')
plt.tight_layout()
plt.show()

# %% [markdown]
# КОРРЕЛЯЦИЯ С ПОКАЗАТЕЛЕМ СЧАСТЬЯ

# %%
correlation_cols = ['Ladder score', 'GDP per capita', 'Social support',
                    'Healthy life expectancy', 'Freedom to make life choices',
                    'Generosity', 'Perceptions of corruption']

correlations = df[correlation_cols].corr()['Ladder score'].sort_values(ascending=False)
for factor, corr in correlations.items():
    print(f"{factor:30}: {corr:+.3f}")
# Out:
# Ladder score                  : +1.000
# Social support                : +0.814
# GDP per capita                : +0.769
# Healthy life expectancy       : +0.759
# Freedom to make life choices  : +0.644
# Perceptions of corruption     : +0.452
# Generosity                    : +0.130

# %% [markdown]
# Анализ выбросов

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))
df[numeric_columns].boxplot()
plt.title('Ящики с усами для всех показателей счастья', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Показатели', fontsize=12)
plt.ylabel('Значения', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Ladder Score - есть один выброс ниже , распределение умеренно скошено влево
# 2. GDP - выброс ниже 2, данные довольно сконцентрированы
# 3. Social support - нет явных выбросов, очень маленький разброс - показатель стабилен среди стран
# 4. Healthy life - большой разброс между 25-м и 75-м процентилем, нет выбросов
# 5. Freedom to make life choice - один выброс
# 6. GENEROSITY - очень маленький разброс, один выброс чуть выше .2
# 7. Perceptions of corruption - один выброс выше .2,

# %%
# Boxplot с группировкой по регионам 
plt.figure(figsize=(14,8))
df.boxplot(column='Ladder score',by='Regional indicator',grid=True,rot=90)
plt.title('Распределение Ladder Score по регионам ', fontsize=16,fontweight='bold',pad=20)
plt.suptitle('')
plt.xlabel('Рег.индикатор')
plt.ylabel("Ladder score")
plt.tight_layout()
plt.show()

# %%
out_sum = []

for column in numeric_columns:
    data_series = df[column]

    q1 = data_series.quantile(.25)
    q3 = data_series.quantile(.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    out = data_series[(data_series < lower_bound) | (data_series > upper_bound)]
    out_perc = (len(out)/len(data_series)) * 100

    out_country = df.loc[out.index, 'Country'].tolist() if len(out) > 0 else []

    out_sum.append({
        'Показатель':column,
        'кол-во выбросов':len(out),
        '% выбросов': out_perc,
        'примеры стран': out_country if out_country else []
    })

# %%
out
# Out:
# 31     0.95358
# 36     0.69812
# 39     0.94966
# 50     0.69833
# 57     0.72707
# 76     0.75188
# 94     0.83500
# 99     0.84146
# 113    1.00000
# 120    0.91078
# 121    0.86525
# Name: Perceptions of corruption, dtype: float64

# %%
out_sum
# Out:
# [{'Показатель': 'Ladder score',
#   'кол-во выбросов': 1,
#   '% выбросов': 0.7142857142857143,
#   'примеры стран': ['Afghanistan']},
#  {'Показатель': 'GDP per capita',
#   'кол-во выбросов': 1,
#   '% выбросов': 0.7142857142857143,
#   'примеры стран': ['Venezuela']},
#  {'Показатель': 'Social support',
#   'кол-во выбросов': 2,
#   '% выбросов': 1.4285714285714286,
#   'примеры стран': ['Afghanistan', 'Benin']},
#  {'Показатель': 'Healthy life expectancy',
#   'кол-во выбросов': 0,
#   '% выбросов': 0.0,
#   'примеры стран': []},
#  {'Показатель': 'Freedom to make life choices',
#   'кол-во выбросов': 4,
#   '% выбросов': 2.857142857142857,
#   'примеры стран': ['Afghanistan', 'Comoros', 'Lebanon', 'Turkiye']},
#  {'Показатель': 'Generosity',
#   'кол-во выбросов': 2,
#   '% выбросов': 1.4285714285714286,
#   'примеры стран': ['Indonesia', 'Myanmar']},
#  {'Показатель': 'Perceptions of corruption',
#   'кол-во выбросов': 11,
#   '% выбросов': 7.857142857142857,
# ...

# %%
out_df = pd.DataFrame(out_sum)
out_df.to_string(index=False)
out_df
# Out:
#                      Показатель  кол-во выбросов  % выбросов  \
# 0                  Ladder score                1    0.714286
# 1                GDP per capita                1    0.714286
# 2                Social support                2    1.428571
# 3       Healthy life expectancy                0    0.000000
# 4  Freedom to make life choices                4    2.857143
# 5                    Generosity                2    1.428571
# 6     Perceptions of corruption               11    7.857143
#
#                                        примеры стран
# 0                                      [Afghanistan]
# 1                                        [Venezuela]
# 2                               [Afghanistan, Benin]
# 3                                                 []
# 4           [Afghanistan, Comoros, Lebanon, Turkiye]
# 5                               [Indonesia, Myanmar]
# 6  [Denmark, Estonia, Finland, Hong Kong, Ireland...

# %%
df[df['Country'] == 'Benin']
# Out:
#     Ranking Country  Regional indicator  Ladder score  GDP per capita  \
# 10      113   Benin  Sub-Saharan Africa        4.3774         4.26801
#
#     Social support  Healthy life expectancy  Freedom to make life choices  \
# 10          0.0794                       64                       0.65654
#
#     Generosity  Perceptions of corruption
# 10     0.27961                    0.43828

# %%
import matplotlib.pyplot as plt 

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
bars1 = ax1.bar(out_df['Показатель'], out_df['кол-во выбросов'],
                color=plt.cm.Set3(range(len(out_df))))
ax1.set_title('количество выбросов по показателям', fontsize=14, fontweight='bold')
ax1.set_xlabel("показатель")
ax1.set_ylabel('количество выбросов')
ax1.set_xticklabels(out_df['Показатель'], rotation=45, ha='right')
ax1.grid(True, alpha=.3, axis='y')
for i, (bar, value) in enumerate(zip(bars1, out_df['кол-во выбросов'])):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, height + 0.1, 
             f'{value}', ha='center', va='bottom')




bars2 = ax2.bar(out_df['Показатель'], out_df['% выбросов'],
                color=plt.cm.Set2(range(len(out_df))))
ax2.set_title('процент выбросов по показателям', fontsize=14, fontweight='bold')
ax2.set_xlabel("показатель")
ax2.set_ylabel('% выбросов')
ax2.set_xticklabels(out_df['Показатель'], rotation=45, ha='right')
ax2.grid(True, alpha=.3, axis='y')
for i, (bar, value) in enumerate(zip(bars2, out_df['% выбросов'])):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, height + 0.1, 
             f'{value:.2f}%', ha='center', va='bottom')





plt.tight_layout()
plt.show()
# Out:
# C:\Users\прог\AppData\Local\Temp\ipykernel_16348\4122118907.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(out_df['Показатель'], rotation=45, ha='right')
# C:\Users\прог\AppData\Local\Temp\ipykernel_16348\4122118907.py:27: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(out_df['Показатель'], rotation=45, ha='right')

# %%
special_cases = ['Afghanistan', 'Benin', 'Venezuela', 'Indonesia', 
                 'Myanmar', 'Denmark', 'Finland', 'Estonia']

for country in special_cases:
    if country in df['Country'].values:
        row = df[df['Country'] == country].iloc[0]
        print(f"\n{country}:")
        print(f"  Регион: {row['Regional indicator']}")
        print(f"  Ранг счастья: {row['Ranking']}")
        print(f"  GDP: {row['GDP per capita']:.2f}")
        print(f"  Соц. поддержка: {row['Social support']:.2f}")
        print(f"  Восприятие коррупции: {row['Perceptions of corruption']:.2f}")
# Out:
# Afghanistan:
#   Регион: South Asia
#   Ранг счастья: 140
#   GDP: 2.93
#   Соц. поддержка: 0.00
#   Восприятие коррупции: 0.15
#
# Benin:
#   Регион: Sub-Saharan Africa
#   Ранг счастья: 113
#   GDP: 4.27
#   Соц. поддержка: 0.08
#   Восприятие коррупции: 0.44
#
# Venezuela:
#   Регион: Latin America and Caribbean
#   Ранг счастья: 78
#   GDP: 0.00
#   Соц. поддержка: 0.82
#   Восприятие коррупции: 0.15
#
# Indonesia:
#   Регион: Southeast Asia
#   Ранг счастья: 79
#   GDP: 6.36
#   Соц. поддержка: 0.73
#   Восприятие коррупции: 0.10
#
# Myanmar:
#   Регион: Southeast Asia
#   Ранг счастья: 115
#   GDP: 4.57
#   Соц. поддержка: 0.61
#   Восприятие коррупции: 0.30
#
# Denmark:
#   Регион: Western Europe
#   Ранг счастья: 2
#   GDP: 8.91
#   Соц. поддержка: 0.94
#   Восприятие коррупции: 0.95
#
# Finland:
#   Регион: Western Europe
#   Ранг счастья: 1
#   GDP: 8.61
#   Соц. поддержка: 0.97
#   Восприятие коррупции: 0.95
#
# Estonia:
#   Регион: Western Europe
#   Ранг счастья: 34
# ...

# %% [markdown]
# # Подготовка данных к прогнозированию

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

df_model = df.copy()

X = df_model.drop(['Ranking','Country','Regional indicator','Ladder score'],axis=1)
y = df_model['Ladder score']

X_train,X_test,y_train,y_test = train_test_split(X,y, train_size=.67,random_state=1)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

feature_names = X.columns.tolist()

# %% [markdown]
# *Базовые модели сравнение*

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

models = {
    'Linear Regression':LinearRegression(),
    'Ridge Regression': Ridge(alpha=1),
    'Lasso Regression': Lasso(selection='random',max_iter=1000),
    'Decision Tree': DecisionTreeRegressor(random_state=1),
    'Random Forest': RandomForestRegressor(n_estimators=100,random_state=1),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100,random_state=1),
    'XGBoost': XGBRegressor(),
    'KNN': KNeighborsRegressor(n_neighbors=5),
    'SVR': SVR(kernel='rbf')  
}

def evalute_model(model, X_train,X_test,y_train,y_test, model_name):
    model.fit(X_train,y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    metrics = {
        "model": model_name,
        "train_rmse":np.sqrt(mean_squared_error(y_train,y_train_pred)),
        "test_rmse":np.sqrt(mean_squared_error(y_test,y_test_pred)),
        'train_mae':np.sqrt(mean_absolute_error(y_train,y_train_pred)),
        'test_mae':np.sqrt(mean_absolute_error(y_test,y_test_pred)),
        'train_r2':r2_score(y_train,y_train_pred),
        'test_r2':r2_score(y_test, y_test_pred)
    }

    return model, metrics, y_test_pred

results = []
predictions = {}

for name,model in models.items():
    print(f'\nобучение: {name}')
    trained_model, metrics, y_pred = evalute_model(model,X_train_scaled,X_test_scaled, y_train,y_test,name)
    results.append(metrics)
    predictions[name] = y_pred

    print(f"   Test R²: {metrics['test_r2']:.4f}")
    print(f"  Test RMSE: {metrics['test_rmse']:.4f}")

results_df = pd.DataFrame(results)
results_df.sort_values('test_r2',ascending=False).to_string(index=False)
# Out:
# обучение: Linear Regression
#    Test R²: 0.8099
#   Test RMSE: 0.4474
#
# обучение: Ridge Regression
#    Test R²: 0.8105
#   Test RMSE: 0.4468
#
# обучение: Lasso Regression
#    Test R²: -0.1643
#   Test RMSE: 1.1072
#
# обучение: Decision Tree
#    Test R²: 0.4781
#   Test RMSE: 0.7413
#
# обучение: Random Forest
#    Test R²: 0.7141
#   Test RMSE: 0.5487
#
# обучение: Gradient Boosting
#    Test R²: 0.6978
#   Test RMSE: 0.5641
#
# обучение: XGBoost
#    Test R²: 0.7025
#   Test RMSE: 0.5597
#
# обучение: KNN
#    Test R²: 0.7990
#   Test RMSE: 0.4601
#
# обучение: SVR
#    Test R²: 0.7977
#   Test RMSE: 0.4616
# ...
